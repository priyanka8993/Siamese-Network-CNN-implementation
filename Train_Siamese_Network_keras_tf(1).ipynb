# %%
import train_siamese

# %%
s3_path = 's3://reshamandi-ml-data/TagsExtraction/flipped_images/'
s3_bucket_name = "reshamandi-ml-data"
train_siamese.train_siamese_network(s3_path,s3_bucket_name)
# Out:
# Creating list of image path..
# Reading images into array...
# Creating image pairs .....
# Create test, train, validation set
# [[[[[182 187 180]
#     [182 187 180]
#     [182 189 182]
#     ...
#     [187 196 195]
#     [189 195 195]
#     [189 195 195]]
#
#    [[183 188 182]
#     [183 188 182]
#     [182 188 184]
#     ...
#     [187 196 195]
#     [187 196 195]
#     [187 196 195]]
#
#    [[184 189 182]
#     [184 189 183]
#     [183 190 184]
#     ...
#     [188 197 196]
#     [187 196 195]
#     [187 196 195]]
#
#    ...
#
#    [[158 164 164]
#     [160 165 168]
#     [160 166 169]
#     ...
#     [151 162 162]
#     [149 161 161]
#     [150 162 162]]
#
#    [[158 164 164]
#     [158 163 167]
#     [158 163 166]
#     ...
#     [148 160 160]
#     [147 161 162]
#     [147 161 162]]
#
#    [[158 164 162]
#     [157 162 165]
#     [157 162 165]
#     ...
#     [146 158 158]
#     [144 158 158]
#     [145 159 159]]]
#
#
#   [[[196 182 153]
#     [190 175 144]
# ...
